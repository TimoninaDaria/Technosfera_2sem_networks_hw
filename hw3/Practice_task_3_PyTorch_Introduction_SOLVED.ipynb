# %% [markdown]
# ## Семинар 3 "Определение ключевых точек лица"

# %% [markdown]
# ## Задание

# %% [markdown]
# Используя датасет из архива решите задачу регрессии для поиска 68-ми ключевых точек лица.
#
# Для обучения и валидации используйте изображения и разметку из папок train и test соответственно.
#
# Для **зачета** дз нужно сделать одно из двух:
#
# 1. Исследовать 6 разных архитектур и написать подробный вывод + мысли почему одна сеть работает лучше чем другая (разные функции активации, глубины сетей, размеры и типы слоев)
# 2. Преодолеть порог MSE=8 на тесте
#
#
# Также до  21 октября 23:59 можно получить до 5 дополнительных баллов за лучшее решение. (За первое место 5 баллов, за второе — 3 балла, за третье — 1 балла.)
#
# Для решения можно пользоваться всем инструментарием, с которым мы познакомимся:  предобученные модели, сверточные сети, любые оптимизаторы, batchnorm, dropout, etc.

# %%
# !pip install pytorch-ignite
# Out:
# Collecting pytorch-ignite
#   Downloading https://files.pythonhosted.org/packages/14/98/0a5b83d82ff245d3de5f09808fb80ff0ed03f6b10933979e6018b1dd0eaa/pytorch_ignite-0.4.2-py2.py3-none-any.whl (175kB)
#      |████████████████████████████████| 184kB 4.8MB/s
# Requirement already satisfied: torch<2,>=1.3 in /usr/local/lib/python3.6/dist-packages (from pytorch-ignite) (1.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch<2,>=1.3->pytorch-ignite) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch<2,>=1.3->pytorch-ignite) (0.16.0)
# Installing collected packages: pytorch-ignite
# Successfully installed pytorch-ignite-0.4.2

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/af/0c/4f41bcd45db376e6fe5c619c01100e9b7531c55791b7244815bac6eac32c/tensorboardX-2.1-py2.py3-none-any.whl (308kB)
#      |████████████████████████████████| 317kB 4.7MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.12.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (50.3.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.1

# %%
# !pwd
# !unzip dataset.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: dataset/train/2844.jpeg
#  extracting: dataset/train/2845.jpeg
#  extracting: dataset/train/2846.jpeg
#  extracting: dataset/train/2847.jpeg
#  extracting: dataset/train/2848.jpeg
#  extracting: dataset/train/2849.jpeg
#  extracting: dataset/train/285.jpeg
#  extracting: dataset/train/2850.jpeg
#  extracting: dataset/train/2851.jpeg
#  extracting: dataset/train/2852.jpeg
#  extracting: dataset/train/2853.jpeg
#  extracting: dataset/train/2854.jpeg
#  extracting: dataset/train/2855.jpeg
#  extracting: dataset/train/2856.jpeg
#  extracting: dataset/train/2857.jpeg
#  extracting: dataset/train/2858.jpeg
#  extracting: dataset/train/2859.jpeg
#  extracting: dataset/train/286.jpeg
#  extracting: dataset/train/2860.jpeg
#  extracting: dataset/train/2861.jpeg
#  extracting: dataset/train/2862.jpeg
#  extracting: dataset/train/2863.jpeg
#  extracting: dataset/train/2864.jpeg
#  extracting: dataset/train/2865.jpeg
#  extracting: dataset/train/2866.jpeg
#  extracting: dataset/train/2867.jpeg
#  extracting: dataset/train/2868.jpeg
#  extracting: dataset/train/2869.jpeg
#  extracting: dataset/train/287.jpeg
#  extracting: dataset/train/2870.jpeg
#  extracting: dataset/train/2871.jpeg
#  extracting: dataset/train/2872.jpeg
#  extracting: dataset/train/2873.jpeg
#  extracting: dataset/train/2874.jpeg
#  extracting: dataset/train/2875.jpeg
#  extracting: dataset/train/2876.jpeg
#  extracting: dataset/train/2877.jpeg
#  extracting: dataset/train/2878.jpeg
#  extracting: dataset/train/2879.jpeg
#  extracting: dataset/train/288.jpeg
#  extracting: dataset/train/2880.jpeg
#  extracting: dataset/train/2881.jpeg
#  extracting: dataset/train/2882.jpeg
#  extracting: dataset/train/2883.jpeg
#  extracting: dataset/train/2884.jpeg
#  extracting: dataset/train/2885.jpeg
#  extracting: dataset/train/2886.jpeg
#  extracting: dataset/train/2887.jpeg
#  extracting: dataset/train/2888.jpeg
#  extracting: dataset/train/2889.jpeg
#  extracting: dataset/train/289.jpeg
#  extracting: dataset/train/2890.jpeg
#  extracting: dataset/train/2891.jpeg
#  extracting: dataset/train/2892.jpeg
#  extracting: dataset/train/2893.jpeg
#  extracting: dataset/train/2894.jpeg
#  extracting: dataset/train/2895.jpeg
#  extracting: dataset/train/2896.jpeg
#  extracting: dataset/train/2897.jpeg
#  extracting: dataset/train/2898.jpeg
#  extracting: dataset/train/2899.jpeg
#  extracting: dataset/train/29.jpeg
#  extracting: dataset/train/290.jpeg
#  extracting: dataset/train/2900.jpeg
#  extracting: dataset/train/2901.jpeg
#  extracting: dataset/train/2902.jpeg
#  extracting: dataset/train/2903.jpeg
#  extracting: dataset/train/2904.jpeg
#  extracting: dataset/train/2905.jpeg
#  extracting: dataset/train/2906.jpeg
#  extracting: dataset/train/2907.jpeg
#  extracting: dataset/train/2908.jpeg
#  extracting: dataset/train/2909.jpeg
#  extracting: dataset/train/291.jpeg
#  extracting: dataset/train/2910.jpeg
#  extracting: dataset/train/2911.jpeg
#  extracting: dataset/train/2912.jpeg
#  extracting: dataset/train/2913.jpeg
#  extracting: dataset/train/2914.jpeg
#  extracting: dataset/train/2915.jpeg
#  extracting: dataset/train/2916.jpeg
#  extracting: dataset/train/2917.jpeg
#  extracting: dataset/train/2918.jpeg
#  extracting: dataset/train/2919.jpeg
#  extracting: dataset/train/292.jpeg
#  extracting: dataset/train/2920.jpeg
#  extracting: dataset/train/2921.jpeg
#  extracting: dataset/train/2922.jpeg
#  extracting: dataset/train/2923.jpeg
#  extracting: dataset/train/2924.jpeg
#  extracting: dataset/train/2925.jpeg
#  extracting: dataset/train/2926.jpeg
#  extracting: dataset/train/2927.jpeg
#  extracting: dataset/train/2928.jpeg
#  extracting: dataset/train/2929.jpeg
#  extracting: dataset/train/293.jpeg
#  extracting: dataset/train/2930.jpeg
#  extracting: dataset/train/2931.jpeg
#  extracting: dataset/train/2932.jpeg
#  extracting: dataset/train/2933.jpeg
#  extracting: dataset/train/2934.jpeg
#  extracting: dataset/train/2935.jpeg
#  extracting: dataset/train/2936.jpeg
#  extracting: dataset/train/2937.jpeg
#  extracting: dataset/train/2938.jpeg
#  extracting: dataset/train/2939.jpeg
#  extracting: dataset/train/294.jpeg
#  extracting: dataset/train/2940.jpeg
#  extracting: dataset/train/2941.jpeg
#  extracting: dataset/train/2942.jpeg
#  extracting: dataset/train/2943.jpeg
#  extracting: dataset/train/2944.jpeg
#  extracting: dataset/train/2945.jpeg
#  extracting: dataset/train/2946.jpeg
#  extracting: dataset/train/2947.jpeg
#  extracting: dataset/train/2948.jpeg
#  extracting: dataset/train/2949.jpeg
#  extracting: dataset/train/295.jpeg
#  extracting: dataset/train/2950.jpeg
#  extracting: dataset/train/2951.jpeg
#  extracting: dataset/train/2952.jpeg
#  extracting: dataset/train/2953.jpeg
#  extracting: dataset/train/2954.jpeg
#  extracting: dataset/train/2955.jpeg
#  extracting: dataset/train/2956.jpeg
#  extracting: dataset/train/2957.jpeg
#  extracting: dataset/train/2958.jpeg
#  extracting: dataset/train/2959.jpeg
#  extracting: dataset/train/296.jpeg
#  extracting: dataset/train/2960.jpeg
#  extracting: dataset/train/2961.jpeg
#  extracting: dataset/train/2962.jpeg
#  extracting: dataset/train/2963.jpeg
#  extracting: dataset/train/2964.jpeg
#  extracting: dataset/train/2965.jpeg
#  extracting: dataset/train/2966.jpeg
#  extracting: dataset/train/2967.jpeg
#  extracting: dataset/train/2968.jpeg
#  extracting: dataset/train/2969.jpeg
#  extracting: dataset/train/297.jpeg
#  extracting: dataset/train/2970.jpeg
#  extracting: dataset/train/2971.jpeg
#  extracting: dataset/train/2972.jpeg
#  extracting: dataset/train/2973.jpeg
#  extracting: dataset/train/2974.jpeg
#  extracting: dataset/train/2975.jpeg
#  extracting: dataset/train/2976.jpeg
#  extracting: dataset/train/2977.jpeg
#  extracting: dataset/train/2978.jpeg
#  extracting: dataset/train/2979.jpeg
#  extracting: dataset/train/298.jpeg
#  extracting: dataset/train/2980.jpeg
#  extracting: dataset/train/2981.jpeg
#  extracting: dataset/train/2982.jpeg
#  extracting: dataset/train/2983.jpeg
#  extracting: dataset/train/2984.jpeg
#  extracting: dataset/train/2985.jpeg
#  extracting: dataset/train/2986.jpeg
#  extracting: dataset/train/2987.jpeg
#  extracting: dataset/train/2988.jpeg
#  extracting: dataset/train/2989.jpeg
#  extracting: dataset/train/299.jpeg
#  extracting: dataset/train/2990.jpeg
#  extracting: dataset/train/2991.jpeg
#  extracting: dataset/train/2992.jpeg
#  extracting: dataset/train/2993.jpeg
#  extracting: dataset/train/2994.jpeg
#  extracting: dataset/train/2995.jpeg
#  extracting: dataset/train/2996.jpeg
#  extracting: dataset/train/77.jpeg
#  extracting: dataset/train/770.jpeg
#  extracting: dataset/train/771.jpeg
#  extracting: dataset/train/772.jpeg
#  extracting: dataset/train/773.jpeg
#  extracting: dataset/train/774.jpeg
#  extracting: dataset/train/775.jpeg
#  extracting: dataset/train/776.jpeg
#  extracting: dataset/train/777.jpeg
#  extracting: dataset/train/778.jpeg
#  extracting: dataset/train/779.jpeg
#  extracting: dataset/train/78.jpeg
#  extracting: dataset/train/780.jpeg
#  extracting: dataset/train/781.jpeg
#  extracting: dataset/train/782.jpeg
#  extracting: dataset/train/783.jpeg
#  extracting: dataset/train/784.jpeg
#  extracting: dataset/train/785.jpeg
#  extracting: dataset/train/786.jpeg
#  extracting: dataset/train/787.jpeg
#  extracting: dataset/train/788.jpeg
#  extracting: dataset/train/789.jpeg
#  extracting: dataset/train/79.jpeg
#  extracting: dataset/train/790.jpeg
#  extracting: dataset/train/791.jpeg
#  extracting: dataset/train/792.jpeg
#  extracting: dataset/train/793.jpeg
#  extracting: dataset/train/794.jpeg
#  extracting: dataset/train/795.jpeg
#  extracting: dataset/train/796.jpeg
#  extracting: dataset/train/797.jpeg
#  extracting: dataset/train/798.jpeg
#  extracting: dataset/train/799.jpeg
#  extracting: dataset/train/8.jpeg
#  extracting: dataset/train/80.jpeg
#  extracting: dataset/train/800.jpeg
#  extracting: dataset/train/801.jpeg
#  extracting: dataset/train/802.jpeg
#  extracting: dataset/train/803.jpeg
#  extracting: dataset/train/804.jpeg
#  extracting: dataset/train/805.jpeg
#  extracting: dataset/train/806.jpeg
#  extracting: dataset/train/807.jpeg
#  extracting: dataset/train/808.jpeg
#  extracting: dataset/train/809.jpeg
#  extracting: dataset/train/81.jpeg
#  extracting: dataset/train/810.jpeg
#  extracting: dataset/train/811.jpeg
#  extracting: dataset/train/812.jpeg
#  extracting: dataset/train/813.jpeg
#  extracting: dataset/train/814.jpeg
#  extracting: dataset/train/815.jpeg
#  extracting: dataset/train/816.jpeg
#  extracting: dataset/train/817.jpeg
#  extracting: dataset/train/818.jpeg
#  extracting: dataset/train/819.jpeg
#  extracting: dataset/train/82.jpeg
#  extracting: dataset/train/820.jpeg
#  extracting: dataset/train/821.jpeg
#  extracting: dataset/train/822.jpeg
#  extracting: dataset/train/823.jpeg
#  extracting: dataset/train/824.jpeg
#  extracting: dataset/train/825.jpeg
#  extracting: dataset/train/826.jpeg
#  extracting: dataset/train/827.jpeg
#  extracting: dataset/train/828.jpeg
#  extracting: dataset/train/829.jpeg
#  extracting: dataset/train/83.jpeg
#  extracting: dataset/train/830.jpeg
#  extracting: dataset/train/831.jpeg
#  extracting: dataset/train/832.jpeg
#  extracting: dataset/train/833.jpeg
#  extracting: dataset/train/834.jpeg
#  extracting: dataset/train/835.jpeg
#  extracting: dataset/train/836.jpeg
#  extracting: dataset/train/837.jpeg
#  extracting: dataset/train/838.jpeg
#  extracting: dataset/train/839.jpeg
#  extracting: dataset/train/84.jpeg
#  extracting: dataset/train/840.jpeg
#  extracting: dataset/train/841.jpeg
#  extracting: dataset/train/842.jpeg
#  extracting: dataset/train/843.jpeg
#  extracting: dataset/train/844.jpeg
#  extracting: dataset/train/845.jpeg
#  extracting: dataset/train/846.jpeg
#  extracting: dataset/train/847.jpeg
#  extracting: dataset/train/848.jpeg
#  extracting: dataset/train/849.jpeg
#  extracting: dataset/train/85.jpeg
#  extracting: dataset/train/850.jpeg
#  extracting: dataset/train/851.jpeg
#  extracting: dataset/train/852.jpeg
#  extracting: dataset/train/853.jpeg
#  extracting: dataset/train/854.jpeg
#  extracting: dataset/train/855.jpeg
#  extracting: dataset/train/856.jpeg
#  extracting: dataset/train/857.jpeg
#  extracting: dataset/train/858.jpeg
#  extracting: dataset/train/859.jpeg
#  extracting: dataset/train/86.jpeg
#  extracting: dataset/train/860.jpeg
#  extracting: dataset/train/861.jpeg
#  extracting: dataset/train/862.jpeg
#  extracting: dataset/train/863.jpeg
#  extracting: dataset/train/864.jpeg
#  extracting: dataset/train/865.jpeg
#  extracting: dataset/train/866.jpeg
#  extracting: dataset/train/867.jpeg
#  extracting: dataset/train/868.jpeg
#  extracting: dataset/train/869.jpeg
#  extracting: dataset/train/87.jpeg
#  extracting: dataset/train/870.jpeg
#  extracting: dataset/train/871.jpeg
#  extracting: dataset/train/872.jpeg
#  extracting: dataset/train/873.jpeg
#  extracting: dataset/train/874.jpeg
#  extracting: dataset/train/875.jpeg
#  extracting: dataset/train/876.jpeg
#  extracting: dataset/train/877.jpeg
#  extracting: dataset/train/878.jpeg
#  extracting: dataset/train/879.jpeg
#  extracting: dataset/train/88.jpeg
#  extracting: dataset/train/880.jpeg
#  extracting: dataset/train/881.jpeg
#  extracting: dataset/train/882.jpeg
#  extracting: dataset/train/883.jpeg
#  extracting: dataset/train/884.jpeg
#  extracting: dataset/train/885.jpeg
#  extracting: dataset/train/886.jpeg
#  extracting: dataset/train/887.jpeg
#  extracting: dataset/train/888.jpeg
#  extracting: dataset/train/889.jpeg
#  extracting: dataset/train/89.jpeg
#  extracting: dataset/train/890.jpeg
#  extracting: dataset/train/891.jpeg
#  extracting: dataset/train/892.jpeg
#  extracting: dataset/train/893.jpeg
#  extracting: dataset/train/894.jpeg
#  extracting: dataset/train/895.jpeg
#  extracting: dataset/train/896.jpeg
#  extracting: dataset/train/897.jpeg
#  extracting: dataset/train/898.jpeg
#  extracting: dataset/train/899.jpeg
#  extracting: dataset/train/9.jpeg
#  extracting: dataset/train/90.jpeg
#  extracting: dataset/train/900.jpeg
#  extracting: dataset/train/901.jpeg
#  extracting: dataset/train/902.jpeg
#  extracting: dataset/train/903.jpeg
#  extracting: dataset/train/904.jpeg
#  extracting: dataset/train/905.jpeg
#  extracting: dataset/train/906.jpeg
#  extracting: dataset/train/907.jpeg
#  extracting: dataset/train/908.jpeg
#  extracting: dataset/train/909.jpeg
#  extracting: dataset/train/91.jpeg
#  extracting: dataset/train/910.jpeg
#  extracting: dataset/train/911.jpeg
#  extracting: dataset/train/912.jpeg
#  extracting: dataset/train/913.jpeg
#  extracting: dataset/train/914.jpeg
#  extracting: dataset/train/915.jpeg
#  extracting: dataset/train/916.jpeg
#  extracting: dataset/train/917.jpeg
#  extracting: dataset/train/918.jpeg
#  extracting: dataset/train/919.jpeg
#  extracting: dataset/train/92.jpeg
#  extracting: dataset/train/920.jpeg
#  extracting: dataset/train/921.jpeg
#  extracting: dataset/train/922.jpeg
#  extracting: dataset/train/923.jpeg
#  extracting: dataset/train/924.jpeg
#  extracting: dataset/train/925.jpeg
#  extracting: dataset/train/926.jpeg
#  extracting: dataset/train/927.jpeg
#  extracting: dataset/train/928.jpeg
#  extracting: dataset/train/929.jpeg
#  extracting: dataset/train/93.jpeg
#  extracting: dataset/train/930.jpeg
#  extracting: dataset/train/931.jpeg
#  extracting: dataset/train/932.jpeg
#  extracting: dataset/train/933.jpeg
#  extracting: dataset/train/934.jpeg
#  extracting: dataset/train/935.jpeg
#  extracting: dataset/train/936.jpeg
#  extracting: dataset/train/937.jpeg
#  extracting: dataset/train/938.jpeg
#  extracting: dataset/train/939.jpeg
#  extracting: dataset/train/94.jpeg
#  extracting: dataset/train/940.jpeg
#  extracting: dataset/train/941.jpeg
#  extracting: dataset/train/942.jpeg
#  extracting: dataset/train/943.jpeg
#  extracting: dataset/train/944.jpeg
#  extracting: dataset/train/945.jpeg
#  extracting: dataset/train/946.jpeg
#  extracting: dataset/train/947.jpeg
#  extracting: dataset/train/948.jpeg
#  extracting: dataset/train/949.jpeg
#  extracting: dataset/train/95.jpeg
#  extracting: dataset/train/950.jpeg
#  extracting: dataset/train/951.jpeg
#  extracting: dataset/train/952.jpeg
#  extracting: dataset/train/953.jpeg
#  extracting: dataset/train/954.jpeg
#  extracting: dataset/train/955.jpeg
#  extracting: dataset/train/956.jpeg
#  extracting: dataset/train/957.jpeg
#  extracting: dataset/train/958.jpeg
#  extracting: dataset/train/959.jpeg
#  extracting: dataset/train/96.jpeg
#  extracting: dataset/train/960.jpeg
#  extracting: dataset/train/961.jpeg
#  extracting: dataset/train/962.jpeg
#  extracting: dataset/train/963.jpeg
#  extracting: dataset/train/964.jpeg
#  extracting: dataset/train/965.jpeg
#  extracting: dataset/train/966.jpeg
#  extracting: dataset/train/967.jpeg
#  extracting: dataset/train/968.jpeg
#  extracting: dataset/train/969.jpeg
#  extracting: dataset/train/97.jpeg
#  extracting: dataset/train/970.jpeg
#  extracting: dataset/train/971.jpeg
#  extracting: dataset/train/972.jpeg
#  extracting: dataset/train/973.jpeg
#  extracting: dataset/train/974.jpeg
#  extracting: dataset/train/975.jpeg
#  extracting: dataset/train/976.jpeg
#  extracting: dataset/train/977.jpeg
#  extracting: dataset/train/978.jpeg
#  extracting: dataset/train/979.jpeg
#  extracting: dataset/train/98.jpeg
#  extracting: dataset/train/980.jpeg
#  extracting: dataset/train/981.jpeg
#  extracting: dataset/train/982.jpeg
#  extracting: dataset/train/983.jpeg
#  extracting: dataset/train/984.jpeg
#  extracting: dataset/train/985.jpeg
#  extracting: dataset/train/986.jpeg
#  extracting: dataset/train/987.jpeg
#  extracting: dataset/train/988.jpeg
#  extracting: dataset/train/989.jpeg
#  extracting: dataset/train/99.jpeg
#  extracting: dataset/train/990.jpeg
#  extracting: dataset/train/991.jpeg
#  extracting: dataset/train/992.jpeg
#  extracting: dataset/train/993.jpeg
#  extracting: dataset/train/994.jpeg
#  extracting: dataset/train/995.jpeg
#  extracting: dataset/train/996.jpeg
#  extracting: dataset/train/997.jpeg
#  extracting: dataset/train/998.jpeg
#  extracting: dataset/train/999.jpeg
#   inflating: dataset/train/face_landmarks.csv

# %%
# %matplotlib inline
import os
import torch
import sys
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torch.nn import MSELoss, Sequential, Linear, Sigmoid, BatchNorm1d, Tanh, L1Loss, Module, Parameter, ELU, ReLU, Conv2d, MaxPool2d, BatchNorm2d, Dropout
from torch.autograd import Variable
import torchvision.models as models
import torchvision.models as models

# Ignore warnings
import warnings


try:
    from tensorboardX import SummaryWriter
except ImportError:
    raise RuntimeError("No tensorboardX package is found. Please install with the command: \npip install tensorboardX")

from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss

# %%
warnings.filterwarnings("ignore")

landmarks_frame = pd.read_csv('dataset/train/face_landmarks.csv')

n = 100
img_name = landmarks_frame.values[n, 0]
landmarks = landmarks_frame.values[n, 1:].astype('float')
landmarks = landmarks.reshape(-1, 2)

print('Image name: {}'.format(img_name))
print('Landmarks shape: {}'.format(landmarks.shape))
print('First 4 Landmarks: {}'.format(landmarks[:4]))

def show_landmarks(image, landmarks):
    """Show image with landmarks"""
    plt.imshow(image, cmap='gray')
    plt.scatter(landmarks[:, 0], landmarks[:, 1], s=10, marker='.', c='red', cmap='rgb')
    plt.pause(0.001)  

plt.figure()
show_landmarks(io.imread(os.path.join('dataset/train/', img_name)),
               landmarks)
plt.show()
# Out:
# Image name: 109.jpeg
# Landmarks shape: (68, 2)
# First 4 Landmarks: [[ 7. 41.]
#  [ 8. 51.]
#  [10. 60.]
#  [13. 70.]]

# %%
def show_landmarks_batch(sample_batch, y_pred=None):
    """Show image with landmarks for a batch of samples."""
    images_batch, landmarks_batch = \
            sample_batch
    batch_size = len(images_batch)
    im_size = images_batch.size(2)

    grid = utils.make_grid(images_batch)
    print(images_batch.numpy().shape)
    plt.imshow(grid.numpy().transpose(1,0,2).reshape(im_size, -1), cmap="gray")

    for i in range(batch_size):
        plt.scatter(landmarks_batch[i, :, 0].numpy() + i * im_size,
                    landmarks_batch[i, :, 1].numpy(),
                    s=10, marker='.', c='r', label='Real')

    if type(y_pred) != type(None):
        for i in range(batch_size):
            plt.scatter(y_pred[i, :, 0] + i * im_size,
                        y_pred[i, :, 1],
                        s=10, marker='.', c='b',  label='Prediction')
        plt.title('Batch from dataloader')
    plt.legend()

# %%
class FaceLandmarksDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.landmarks_frame.iloc[idx, 0])
        image = io.imread(img_name)
        landmarks = self.landmarks_frame.iloc[idx, 1:].values.astype('float')
        landmarks = landmarks.reshape(-1, 2)
        sample = image, landmarks

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image, landmarks = sample

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h,
                      left: left + new_w]

        landmarks = landmarks - [left, top]

        return image, landmarks




class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, landmarks = sample
        #image = image[None, ...]
        image = np.array([image] * 1)
        #print(image.shape)
        return torch.from_numpy(image).type(torch.float), torch.from_numpy(landmarks).type(torch.float)

# %%
train_dataset = FaceLandmarksDataset(csv_file='dataset/train/face_landmarks.csv',
                                     root_dir='dataset/train',
                                     transform=ToTensor())

test_dataset = FaceLandmarksDataset(csv_file='dataset/test/face_landmarks.csv',
                                     root_dir='dataset/test',
                                     transform=ToTensor())

# %%
def get_data_loaders(train_batch_size=64, val_batch_size=64):

    train_loader = DataLoader(
        train_dataset, batch_size=train_batch_size, shuffle=True
    )

    test_loader = DataLoader(
        test_dataset, batch_size=val_batch_size, shuffle=False
    )

    return train_loader, test_loader

# %%
class Net(Module):
    def __init__(self):
        super().__init__()
        self.seq1 = Sequential(Conv2d(1, 12, 3, padding=1), 
                                         Tanh(),
                                         BatchNorm2d(num_features=12),
                                         MaxPool2d(2),
                                         Conv2d(12, 12, 3, padding=1),
                                         MaxPool2d(2))
        self.seq2 = Sequential(Linear(24*24*12, 200),
                                           BatchNorm1d(num_features=200),
                                           Tanh(),
                                           Linear(200, 2 * 68))
    def forward(self, x):
        x = self.seq1(x)
        x = x.view(x.size(0), -1)
        x = self.seq2(x)
        return x.view(x.shape[0], 68, 2)

# %%
network = Net()
train_dataloader, test_dataloader = get_data_loaders()
writer = SummaryWriter(filename_suffix='first', logdir="out_logs")

device = "cpu"

if torch.cuda.is_available():
    device = "cuda"

device = "cpu"

criterion = MSELoss()
optim = torch.optim.Adam
learning_rate = 0.01
max_epochs = 50

optimizer = optim(network.parameters(), lr=learning_rate)

trainer = create_supervised_trainer(network, optimizer, criterion, device=device)
evaluator = create_supervised_evaluator(
    network, metrics={"L2 loss": Loss(criterion), "L1 loss": Loss(L1Loss())}, device=device
)

training_history = {'l1':[],'l2':[]}
validation_history = {'l1':[],'l2':[]}
last_epoch = []

# %%
@trainer.on(Events.ITERATION_COMPLETED(every=10))
def log_training_loss(engine):
    writer.add_scalar("training/loss", engine.state.output, engine.state.iteration)
    writer.flush()


@trainer.on(Events.EPOCH_COMPLETED)
def log_training_results(trainer):
    evaluator.run(train_dataloader)
    metrics = evaluator.state.metrics
    l2_train = metrics["L2 loss"]
    l1_train = metrics['L1 loss']
    last_epoch.append(0)
    training_history['l2'].append(l2_train)
    training_history['l1'].append(l1_train)
    writer.add_scalar("training/epoch_loss", l2_train, trainer.state.epoch)
    
    evaluator.run(test_dataloader)
    metrics = evaluator.state.metrics
    l2 = metrics["L2 loss"]
    l1 = metrics['L1 loss']
    validation_history['l2'].append(l2)
    validation_history['l1'].append(l1)
    
    writer.add_scalar("validation/epoch_loss", l2, trainer.state.epoch)
    writer.flush()
    
    sys.stdout.write("\rTraining/Validation Results - Epoch: {}  Avg MSE: {:.2f} / {:.2f} Avg MAE: {:.2f} / {:.2f}"
          .format(trainer.state.epoch, l2_train, l2, l1_train, l1))

# %%
trainer.run(train_dataloader, max_epochs=max_epochs)
# Out:
# Training/Validation Results - Epoch: 50  Avg MSE: 1.99 / 7.05 Avg MAE: 1.08 / 1.83
# State:
# 	iteration: 4900
# 	epoch: 50
# 	epoch_length: 98
# 	max_epochs: 50
# 	output: 2.499337911605835
# 	batch: <class 'list'>
# 	metrics: <class 'dict'>
# 	dataloader: <class 'torch.utils.data.dataloader.DataLoader'>
# 	seed: <class 'NoneType'>
# 	times: <class 'dict'>

# %%
plt.figure(figsize=(12, 5))
plt.plot(training_history['l2'][1:], label='Train')
plt.plot(validation_history['l2'][1:], label='Test')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(loc=0, fontsize=16)
plt.grid('on')
plt.show()

# %%
_, test_dataloader = get_data_loaders(val_batch_size=2)

images_batch = next(iter(test_dataloader))
x, y = images_batch
y_pred = network(x)
y_pred = y_pred.data.numpy()
show_landmarks_batch(images_batch, y_pred)

# %%
import torch
import torchvision
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms

# %%
writer = SummaryWriter("out_logs/exp2")

# %%
for x,y in train_dataloader:
    break

# %%
writer.add_graph(network, x)
writer.flush()

# %%
# Будем использовать первый слой сети в качестве feature extractor
# с помощью writer.add_embedding визуализируем полученные признаки
# резульат появится во вкладке PROJECTOR
_, test_dataloader = get_data_loaders(val_batch_size=20)

images_batch = next(iter(test_dataloader))




embedder = list(network.modules())[1]

features = embedder(images_batch[0].view(images_batch[0].shape[0], -1))
writer.add_embedding(features,global_step=2)
writer.flush()

# %% [markdown]
# # Links
#
# [Официальная страница ignite](https://pytorch.org/ignite/index.html)
#
# [Официальная страница PyTorch Lightning](https://github.com/PyTorchLightning/pytorch-lightning)
